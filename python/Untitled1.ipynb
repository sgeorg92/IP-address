# %%
import os
pwd="C:/Users/sarah/Dropbox/Upenn Year 3/paper/IP Address/arin data/1"
os.chdir(pwd)
import filecmp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from datetime import datetime
import ipaddress
from matplotlib.pyplot import *

       
df_list = [pd.read_csv('delegated-nro-extended-20190101.txt',header=None,dtype=str,delimiter="|",skiprows=5).assign(date=os.path.basename('delegated-nro-extended-20190101.txt'))]
big_df = pd.concat(df_list)
[big_df[2]!='asn']
# Out:
#               0   1     2            3   4         5          6  \
# 0          arin  US   asn            1   1  20010920   assigned
# 1          arin  US   asn            2   1  19910110   assigned
# 2          arin  US   asn            3   1  00000000   assigned
# 3          arin  US   asn            4   1  19840222   assigned
# 4          arin  US   asn            5   1  19840202   assigned
# 5          arin  US   asn            6   1  19840202   assigned
# 6       ripencc  GB   asn            7   1  19930901   assigned
# 7          arin  US   asn            8   1  19840326   assigned
# 8          arin  US   asn            9   1  19840417   assigned
# 9          arin  US   asn           10   1  00000000   assigned
# 10         arin  US   asn           11   1  19840704   assigned
# 11         arin  US   asn           12   1  19840705   assigned
# 12         arin  US   asn           13   1  19840716   assigned
# 13         arin  US   asn           14   1  00000000   assigned
# ...
