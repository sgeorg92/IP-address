# %%
import os
pwd="C:/Users/sarah/Dropbox/Upenn Year 3/paper/IP Address/arin data/1"
os.chdir(pwd)
import filecmp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from datetime import datetime
import ipaddress
from matplotlib.pyplot import *

       
df_list = [pd.read_csv('delegated-nro-extended-20190102.txt',header=None,dtype=str,delimiter="|",skiprows=5).assign(date=os.path.basename('delegated-nro-extended-20190102.txt'))]
big_df = pd.concat(df_list)
big_df[big_df[2]!='asn']
# Out:
#               0   1     2            3         4         5          6  \
# 87864      iana  ZZ  ipv4      0.0.0.0  16777216  19830101       ietf
# 87865     apnic  AU  ipv4      1.0.0.0       256  20110811   assigned
# 87866     apnic  CN  ipv4      1.0.1.0       256  20110414   assigned
# 87867     apnic  CN  ipv4      1.0.2.0       512  20110414   assigned
# 87868     apnic  AU  ipv4      1.0.4.0      1024  20110412   assigned
# 87869     apnic  CN  ipv4      1.0.8.0      2048  20110412   assigned
# 87870     apnic  JP  ipv4     1.0.16.0      4096  20110412   assigned
# 87871     apnic  CN  ipv4     1.0.32.0      8192  20110412   assigned
# 87872     apnic  JP  ipv4     1.0.64.0     16384  20110412   assigned
# 87873     apnic  TH  ipv4    1.0.128.0     32768  20110408   assigned
# 87874     apnic  CN  ipv4      1.1.0.0       256  20110414   assigned
# 87875     apnic  AU  ipv4      1.1.1.0       256  20110811   assigned
# ...
